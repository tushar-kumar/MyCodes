# %%
import tabula
df = tabula.read_pdf('R1.pdf',pages = "all")
print(df[1])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[6], line 2
#       1 import tabula
# ----> 2 df = tabula.read_pdf('R1.pdf',pages = "all")
#       3 print(df[1])
#
# File /lib/python3.10/site-packages/tabula/io.py:426, in read_pdf(input_path, output_format, encoding, java_options, pandas_options, multiple_tables, user_agent, use_raw_url, pages, guess, area, relative_area, lattice, stream, password, silent, columns, relative_columns, format, batch, output_path, options)
#     421     raise ValueError(
#     422         "{} is empty. Check the file, or download it manually.".format(path)
#     423     )
#     425 try:
# --> 426     output = _run(java_options, tabula_options, path, encoding)
#     427 finally:
#     428     if temporary:
#
# File /lib/python3.10/site-packages/tabula/io.py:87, in _run(java_options, options, path, encoding)
#      84     args.append(path)
# ...
